# %%
import pandas as pd
import re
# Load the datasets
job_titles_df = pd.read_csv('all_titles.csv')
df = pd.read_csv('Company_type.csv')

# %%
def clean_job_title(title):
    # Define a dictionary for special cases to handle variations of 'Co-Founder' and 'Co-Owner' uniformly
    special_cases = {
        'Co-Owner': 'Co-Owner', 
        'Co-Founder': 'Co-Founder',
        'Co Founder': 'Co-Founder',  # Including space variations
        'Co-founder': 'Co-Founder',  # Including hyphen variations
        'Co Owner': 'Co-Owner',      # Including space variations
        'Co-owner': 'Co-Owner'       # Including hyphen variations
    }
    # Iterate through special cases to find and replace variations with a standard format
    for special_case, replacement in special_cases.items():
        # Use regex to match titles with flexible spacing and hyphens
        if re.search(special_case.replace(' ', '[ -]*'), title, re.IGNORECASE):
            return replacement
    # Handle the specific case of 'Co Founder & Managing Director' to classify as 'Co-Founder'
    if 'co founder' in title.lower() and 'managing director' in title.lower():
        return 'Co-Founder'
    # Loop through predefined job titles to find a match with the current title
    for index, row in job_titles_df.iterrows():
        # Use regex for case-insensitive matching of job titles
        if re.search(row['Title'], title, re.IGNORECASE):
            return row['Title']
    # Default handling for titles containing 'Director' or 'Manager' if no specific title is matched
    if 'Director' in title:
        return 'Director'
    elif 'Manager' in title:
        return 'Manager'
    # Return None if no suitable title is found
    return None

# Apply the cleaning function to each entry in the 'Title' column of the dataframe
df['cleaned_title'] = df['Title'].apply(clean_job_title)

# Display the counts of original and cleaned titles for comparison
df[['Title','cleaned_title']].value_counts()
# Out:
# Title                                                   cleaned_title
# Director                                                Director                                  4
# Managing Director                                       Managing Director                         4
# Owner                                                   Owner                                     4
# Chief Executive Officer                                 Chief Executive Officer                   3
# Business Owner                                          Owner                                     2
# CEO/President                                           President                                 2
# CEO                                                     CEO                                       2
# Sales Director                                          Sales Director                            2
# Director of Sales                                       Director of Sales                         2
# Founder                                                 Founder                                   2
# Marketing Director                                      Marketing Director                        1
# Event Director                                          Event Director                            1
# Executive Sales Director                                Sales Director                            1
# Fleet Maintenance Director                              Fleet Maintenance Director                1
# Founder and Director                                    Founder                                   1
# Latin America Director                                  Director                                  1
# Owner & CEO                                             Owner                                     1
# Marketing and IT Director                               Marketing and IT Director                 1
# Director, Operations & E-Commerce                       Director                                  1
# Owner of Evridges inc                                   Owner                                     1
# P&N Distribution Director of New Business Development   Director                                  1
# President - Chief Executive Officer                     President                                 1
# President/ Co-Owner                                     Co-Owner                                  1
# Pure Soy Candle Company : Artistic Director / Founder   Founder                                   1
# Sales & Marketing director                              Marketing Director                        1
# Small Business Owner                                    Owner                                     1
# Technical Director                                      Director                                  1
# Division Operations Director                            Operations Director                       1
# Director of eBusiness                                   Director of eBusiness                     1
# Director, Human Resources                               Director                                  1
# Director, HR Planning and Operations                    Director                                  1
# Commercial Director                                     Commercial Director                       1
# Company Director                                        Director                                  1
# Creative Director                                       Creative Director                         1
# Creative Director/Digital Press Operator                Creative Director                         1
# Customer Experience Director                            Customer Experience Director              1
# Customer Service Director                               Customer Service Director                 1
# Director Marketing & Exports                            Director Marketing & Exports              1
# Director Relations Representative on behalf of the CEO  CEO                                       1
# Director of Business Development                        Director of Business Development          1
# Director of Construction                                Director of Construction                  1
# Director of Government Contracts                        Director of Government Contracts          1
# Director of HR                                          Director of HR                            1
# Director of Logistics                                   Director of Logistics                     1
# Director of Operations                                  Director of Operations                    1
# Director of Operations + Account Manager                Director of Operations                    1
# Director of Project Management                          Director of Project Management            1
# Director of Revenue Management                          Director of Revenue Management            1
# Director of Safety and Risk Management                  Director of Safety and Risk Management    1
# Director of Sales & Marketing                           Director of Sales                         1
# co owner                                                Co-Owner                                  1
# Name: count, dtype: int64
